# %% [markdown]
# # load all the required packages

# %%
import logging
import time
import datetime
import pandas as pd
import ast
from plotly.offline import init_notebook_mode
from common.functions import find_curve_elbow_idx_based_on_max_dist, normalize_dict
from socialtree_functions import visualize_trees_and_graphs
from config import config
init_notebook_mode(connected=True)
# Out:
# <script type="text/javascript">window.PlotlyConfig = {MathJaxConfig: 'local'};</script><script type="text/javascript">if (window.MathJax) {MathJax.Hub.Config({SVG: {font: "STIX-Web"}});}</script><script>requirejs.config({paths: { 'plotly': ['https://cdn.plot.ly/plotly-latest.min']},});if(!window._Plotly) {require(['plotly'],function(plotly) {window._Plotly=plotly;});}</script>

# %%
# _logger = logging.getLogger()
# assert len(_logger.handlers) == 1
# handler = _logger.handlers[0]
# handler.setLevel(logging.DEBUG)

# %% [markdown]
# configure the logger to propagate the messages to the notebook using a workaround shown on https://stackoverflow.com/a/50670775/2262424

# %%
# workaround via specifying an invalid value first
# %config Application.log_level='WORKAROUND'  # this will throw an ERROR, don't worry, it's part of the plan
# %config Application.log_level='DEBUG'
logging.getLogger().setLevel(logging.DEBUG)
_logger = logging.getLogger()
# Out:
# ERROR:root:The 'log_level' trait of an IPKernelApp instance must be any of (0, 10, 20, 30, 40, 50, 'DEBUG', 'INFO', 'WARN', 'ERROR', 'CRITICAL'), but a value of 'WORKAROUND' <class 'str'> was specified.

# %% [markdown]
# # retrieve articles

# %% [markdown]
# This part is coming soon

# %% [markdown]
# # load the retrieved articles and get the relevant articles to be summarized

# %% [markdown]
# define the query

# %%
story_id = "independence"  # this is just an id... you can use any random string

# %% [markdown]
# load (or retrieve) the articles

# %%
tagged_articles_df = pd.read_csv("../data/%s_ranked_articles.csv" % str(story_id))

# %%
print(tagged_articles_df.shape)
tagged_articles_df.head()
# Out:
# (3251, 6)
#                                                  url  \
# 0  http://www.irishtimes.com/news/world/uk/sturge...
# 1  http://www.irishtimes.com/news/ireland/irish-n...
# 2  http://www.irishtimes.com/news/world/europe/pr...
# 3  http://www.irishtimes.com/news/world/uk/scotti...
# 4  http://www.irishtimes.com/news/world/uk/scotti...
#
#                                   t         epoch  \
# 0  2016-05-09T13:50:50.253590+00:00  1.462802e+09
# 1  2016-08-14T16:31:23.749013+00:00  1.471192e+09
# 2         2015-09-27T21:55:00+00:00  1.443391e+09
# 3         2015-11-23T14:06:00+00:00  1.448288e+09
# 4         2015-11-23T13:54:00+00:00  1.448287e+09
#
#                                      hashtag_profile  \
# 0                                 {'#scotland': 1.0}
# 1                                                 {}
# 2  {'#catalonia': 0.5196211096075778, '#spain': 0...
# 3                                                 {}
# 4                                                 {}
#
#                                          tag_profile     score
# 0  {'#scotland': 0.75, 'holyrood': 0.05, 'nicola_...  0.002277
# 1  {'cork': 0.05, 'independence_museum': 0.05, 'k...  0.002154
# 2  {'#catalonia': 0.38971583220568334, '#spain': ...  0.002107
# 3  {'group': 0.05, 'independence': 0.05, 'scottis...  0.002039
# 4  {'group': 0.05, 'independence': 0.05, 'scottis...  0.001993

# %% [markdown]
# As we don't have an annotated ground truth set of articles relevant to each query, we will filter out the articles with negligibly small relevance to the query and will assume that all the remaining articles are relevant.
# ***
# find the article cutoff location based on an elbow of the cumulative distribution exponent...

# %%
article_scores = sorted(tagged_articles_df['score'].tolist(), reverse=True)
article_rel_cutoff = article_scores[find_curve_elbow_idx_based_on_max_dist(article_scores)] / max(article_scores)
del article_scores

# %%
if tagged_articles_df.shape[0] > config.MIN_N_ARTICLES_FOR_ELBOW_CUT:
    article_rel_cutoff_score = min(
        sorted(
            tagged_articles_df['score'].tolist(), reverse=True
        )[min(config.MIN_N_ARTICLES_FOR_ELBOW_CUT, tagged_articles_df.shape[0]) - 1],
        article_rel_cutoff * tagged_articles_df['score'].max()
    )
    summary_articles_df = tagged_articles_df[
        tagged_articles_df['score'] >= article_rel_cutoff_score
    ].copy()
else:
    # this makes sense especially when the query is matched only on headlines or pseudoarticles
    summary_articles_df = tagged_articles_df.copy()

# %%
if config.EXPORT_RELEVANT_ARTICLES_TO_CSV_FILENAME:
    summary_articles_df.to_csv(
        config.EXPORT_RELEVANT_ARTICLES_TO_CSV_FILENAME % str(story_id), header=True, index=False
    )

# %% [markdown]
# re-normalizing the article scores after the junk is cut off

# %%
summary_articles_df['score'] = summary_articles_df[['score']].apply(lambda x: x / x.sum())

# %% [markdown]
# convert the fields to their correct types

# %%
summary_articles_df.loc[summary_articles_df['hashtag_profile'].notnull(), 'hashtag_profile'] = \
    summary_articles_df[summary_articles_df['hashtag_profile'].notnull()]['hashtag_profile'].map(ast.literal_eval)
summary_articles_df.loc[summary_articles_df['tag_profile'].notnull(), 'tag_profile'] = \
    summary_articles_df[summary_articles_df['tag_profile'].notnull()]['tag_profile'].map(ast.literal_eval)

# %%
summary_articles_df['epoch'] = summary_articles_df['epoch'].astype(int)
summary_articles_df['t'] = pd.to_datetime(summary_articles_df['t']).map(lambda t: t.to_pydatetime())

# %% [markdown]
# create supporting fields

# %%
summary_articles_df['tags_list'] = summary_articles_df['tag_profile'].map(lambda p: list(p.keys()))

# %% [markdown]
# create the missing fields

# %%
summary_articles_df['keyword_profile'] = summary_articles_df['tag_profile'].map(lambda p: normalize_dict(dict((t, s) for (t, s) in p.items() if "#" not in t)))

# %%
summary_articles_df['keywords_list'] = summary_articles_df['keyword_profile'].map(lambda p: list(p.keys()))

# %% [markdown]
# in case if there is no <tt>'id'</tt> field in the article dataframe, create one

# %%
summary_articles_df['id'] = summary_articles_df.index

# %%
print(summary_articles_df.shape)
summary_articles_df.head()
# Out:
# (384, 10)
#                                                  url  \
# 0  http://www.irishtimes.com/news/world/uk/sturge...
# 1  http://www.irishtimes.com/news/ireland/irish-n...
# 2  http://www.irishtimes.com/news/world/europe/pr...
# 3  http://www.irishtimes.com/news/world/uk/scotti...
# 4  http://www.irishtimes.com/news/world/uk/scotti...
#
#                                  t       epoch  \
# 0 2016-05-09 13:50:50.253590+00:00  1462801850
# 1 2016-08-14 16:31:23.749013+00:00  1471192283
# 2        2015-09-27 21:55:00+00:00  1443390900
# 3        2015-11-23 14:06:00+00:00  1448287560
# 4        2015-11-23 13:54:00+00:00  1448286840
#
#                                      hashtag_profile  \
# 0                                 {'#scotland': 1.0}
# 1                                                 {}
# 2  {'#catalonia': 0.5196211096075778, '#spain': 0...
# 3                                                 {}
# 4                                                 {}
#
#                                          tag_profile     score  \
# 0  {'#scotland': 0.75, 'holyrood': 0.05, 'nicola_...  0.005394
# 1  {'cork': 0.05, 'independence_museum': 0.05, 'k...  0.005103
# 2  {'#catalonia': 0.38971583220568334, '#spain': ...  0.004993
# 3  {'group': 0.05, 'independence': 0.05, 'scottis...  0.004831
# 4  {'group': 0.05, 'independence': 0.05, 'scottis...  0.004722
#
#                                            tags_list  \
# 0  [#scotland, holyrood, nicola_sturgeon, parliam...
# 1  [cork, independence_museum, kilmurry, presiden...
# 2  [#catalonia, #spain, catalonia, election, gove...
# 3       [group, independence, scottish, tens, women]
# 4       [group, independence, scottish, tens, women]
#
#                                      keyword_profile  \
# 0  {'holyrood': 0.2, 'nicola_sturgeon': 0.2, 'par...
# 1  {'cork': 0.2, 'independence_museum': 0.2, 'kil...
# 2  {'catalonia': 0.2, 'election': 0.2, 'governmen...
# 3  {'group': 0.2, 'independence': 0.2, 'scottish'...
# 4  {'group': 0.2, 'independence': 0.2, 'scottish'...
#
#                                        keywords_list  id
# 0  [holyrood, nicola_sturgeon, parliament, scotla...   0
# 1  [cork, independence_museum, kilmurry, presiden...   1
# 2  [catalonia, election, government, parties, spain]   2
# 3       [group, independence, scottish, tens, women]   3
# 4       [group, independence, scottish, tens, women]   4

# %% [markdown]
# at this stage we have the set of relevant articles and we'll proceed with summary extraction

# %% [markdown]
# # extract a SocialTree

# %%
story_info = ""
if config.CREATE_SOCIALTREE_FLAG:
    tttt = time.time()
    timing_marks = [('start', time.time())]
    tag_score_dict, timing_marks, story_info, tag_recall_div, tag_profile_div, \
    tag_support_div, g_div, t_plain_div, t_days_div, t_tag_profile_div, t_basic_div, t_simple_div, t_div = \
        visualize_trees_and_graphs(
            story_id=story_id,
            articles_df=summary_articles_df.copy(),
            timing_marks=timing_marks,
            story_info=story_info,
            tag_profile_field_name=config.SOCIALTREE_TAG_PROFILE_FIELD,
            tag_blacklist=config.HASHTAG_BLACKLIST + config.KEYWORD_BLACKLIST,
            redundancy_conf_thres=config.TAG_REDUNDANCY_CONF_THRES,
            lexical_redundancy_prefix=config.TAG_LEXICAL_REDUNDANCY_PREFIX,
            lexical_redundancy_suffix=config.TAG_LEXICAL_REDUNDANCY_SUFFIX,
            min_profile_size=config.MIN_TAG_PROFILE_SIZE,
            plot_stats_flag=config.PLOT_TAG_PROFILE_STATS_FLAG,
            tag_list_field_name=config.SOCIALTREE_TAG_LIST_FIELD,
            tag_field_blacklist=config.HASHTAG_BLACKLIST + config.KEYWORD_BLACKLIST,
            visualize_tree_flag=config.CREATE_SOCIALTREE_FLAG,
            importance_weighting_mode=config.TAG_IMPORTANCE_WEIGHTING_MODE,
            story_distance_resolution=config.TAG_SUBSTORY_DISTANCE_RESOLUTION,
            pattern_type=config.TAG_PATTERN_TYPE,
            min_pattern_support=config.MIN_TAG_PATTERN_SUPPORT,
            visualize_intermediate_trees_flag=config.VISUALIZE_INTERMEDIATE_TREES_FLAG
        )
    _logger.debug("SocialTree extraction took %.4f seconds" % (time.time() - tttt))
    del tttt
    _logger.info(
        "--- the tag profile of the story is %s ---" % sorted(
            [(h, round(s, 4)) for h, s in tag_score_dict.items()],
            key=lambda x: x[1], reverse=True
        )
    )
    _logger.info("#" * 29 + " CREATED A SOCIALTREE " + "#" * 29 + "\n")
else:
    tag_recall_div, tag_profile_div = "", ""
    tag_support_div, g_div, t_plain_div, t_days_div, t_tag_profile_div, t_basic_div, t_simple_div, t_div = \
        "", "", "", "", "", "", "", ""
# Out:
# INFO:socialtree_functions:-------------------------- EXTRACTING THE TAG PROFILE --------------------------
# INFO:profile_functions:started replacing the lexiacally redundant tags
# INFO:profile_functions:--- started the story tag profile extraction ---
# INFO:profile_functions:initially there were 1007 tags selected for story's profile tag_profile
# INFO:common.pattern_functions:read the rules from 'patterns/story_patterns_independence_tag_profile_rules.out' and produced a df of shape (3685, 11)
# INFO:common.pattern_functions:found 228 redundant sets of items with 100% conditional probability of co-occurrence on both directions,
# as a result, 475 items will be removed from the item profile and later will be added to their co-occurring items
# INFO:profile_functions:after the redundancy removal, 532 tags compose story's profile tag_profile
# INFO:profile_functions:the cuttoff point should be ('#hong', 0.006813480696078762) based on max dist
# INFO:profile_functions:--- finished the story tag_profile profile extraction in 1.149 seconds (1.1 seconds since start) ---
# INFO:profile_functions:--- finished the tag_profile plot preparations in 0.596 seconds (1.7 seconds since start) ---
# INFO:socialtree_functions:-------------------------- EXTRACTED THE TAG PROFILE ---------------------------
# INFO:socialtree_functions:------------------------------ CREATING A TAG TREE -----------------------------
# INFO:common.pattern_functions:read the patterns from 'patterns/story_patterns_independence_tags_list_frequent.out' and produced a df of shape (130, 5)
# INFO:common.pattern_functions:there are 130 patterns with support>=-1 mined from the retrieved documents
# INFO:socialtree_functions:--- mined frequent patterns in 0.039 seconds (1.8 seconds since start) ---
# INFO:socialtree_functions:--- starting the graph construction and the tree extraction ---
# DEBUG:common.pattern_functions:finished getting the document ids for patterns of length 2 in 0.01 sec
# DEBUG:common.pattern_functions:finished getting the document ids for patterns of length 3 in 0.01 sec
# DEBUG:common.pattern_functions:finished getting the document ids for patterns of length 4 in 0.01 sec
# DEBUG:common.pattern_functions:finished getting the document ids for patterns of length 5 in 0.01 sec
# INFO:common.graph_functions:there are 19 nodes with 52 edges + 1 isolates with support>=1
# INFO:socialtree_functions:--- constructed the graph in 0.007 seconds (2.2 seconds since start) ---
# INFO:socialtree_functions:--- set the node attributes in 0.082 seconds (2.3 seconds since start) ---
# <div id="00a4184a-ed7d-40af-b1a5-3d9513edcb38" style="height: 720.0px; width: 1320px;" class="plotly-graph-div"></div><script type="text/javascript">require(["plotly"], function(Plotly) { window.PLOTLYENV=window.PLOTLYENV || {};window.PLOTLYENV.BASE_URL="https://plot.ly";Plotly.newPlot("00a4184a-ed7d-40af-b1a5-3d9513edcb38", [{"hoverinfo": "none", "line": {"color": "#888", "width": 1.3157894736842106}, "mode": "lines", "x": [0.44626639220946834, 0.16735111532748553, null], "y": [0.17221944025368557, 0.0671251960816718, null], "type": "scatter", "uid": "714f3770-b426-46ed-9217-4a4977c715c4"}, {"hoverinfo": "none", "line": {"color": "#888", "width": 4.473684210526316}, "mode": "lines", "x": [0.44626639220946834, 0.582146397043463, null], "y": [0.17221944025368557, 0.39347193121892526, null], "type": "scatter", "uid": "9f488f0a-744f-4043-945d-dd662de9f4b8"}, {"hoverinfo": "none", "line": {"color": "#888", "width": 4.342105263157895}, "mode": "lines", "x": [0.44626639220946834, 0.6781047265835408, null], "y": [0.17221944025368557, 0.17721374413906812, null], "type": "scatter", "uid": "80154b08-ce20-4ad1-bea6-c95a6732eb58"}, {"hoverinfo": "none", "line": {"color": "#888", "width": 1}, "mode": "lines", "x": [0
# INFO:common.graph_functions:--- plotted the time-aware_query-aware MST in 2.467 seconds (5.3 seconds since start) ---
# INFO:socialtree_functions:------------------------------ CREATED A TAG TREE ------------------------------
# DEBUG:root:SocialTree extraction took 5.3483 seconds
# INFO:root:--- the tag profile of the story is [('#spain$', 0.0917), ('#catalonia$', 0.0786), ('#brexit', 0.0733), ('#scotland$', 0.0519), ('#catalan$', 0.041), ('#indyref2', 0.0374), ('#hongkong', 0.0226), ('#independence', 0.0202), ('#china$', 0.0191), ('#barcelona', 0.012), ('#uk', 0.0118), ('#eu', 0.0105), ('#eritrea', 0.0105), ('#taiwan', 0.01), ('#snp$', 0.0097), ('#bangladesh', 0.0084), ('#ireland$', 0.0078), ('nicola_sturgeon', 0.0073), ('#sports', 0.007), ('#hong', 0.0068)] ---
# INFO:root:############################# CREATED A SOCIALTREE #############################

# %% [markdown]
# # extract a KeywordTree

# %%
if config.CREATE_KEYWORDTREE_FLAG:
    _logger.info("#" * 28 + " CREATING A KEYWORDTREE " + "#" * 28)
    tttt = time.time()
    keyword_score_dict, timing_marks, story_info, keyword_recall_div, keyword_profile_div, \
    k_support_div, g_div_k, t_plain_div_k, t_days_div_k, t_tag_profile_div_k, t_basic_div_k, t_simple_div_k, t_div_k = \
        visualize_trees_and_graphs(
            story_id=story_id,
            articles_df=summary_articles_df.copy(),
            timing_marks=timing_marks,
            story_info=story_info,
            tag_profile_field_name=config.KEYWORDTREE_TAG_PROFILE_FIELD,
            tag_blacklist=config.KEYWORD_BLACKLIST,
            redundancy_conf_thres=config.KEYWORD_REDUNDANCY_CONF_THRES,
            lexical_redundancy_prefix=config.KEYWORD_LEXICAL_REDUNDANCY_PREFIX,
            lexical_redundancy_suffix=config.KEYWORD_LEXICAL_REDUNDANCY_SUFFIX,
            min_profile_size=config.MIN_KEYWORD_PROFILE_SIZE,
            plot_stats_flag=config.PLOT_KEYWORD_PROFILE_STATS_FLAG,
            tag_list_field_name=config.KEYWORDTREE_TAG_LIST_FIELD,
            tag_field_blacklist=config.KEYWORD_BLACKLIST,
            visualize_tree_flag=config.CREATE_KEYWORDTREE_FLAG,
            importance_weighting_mode=config.KEYWORD_IMPORTANCE_WEIGHTING_MODE,
            story_distance_resolution=config.KEYWORD_SUBSTORY_DISTANCE_RESOLUTION,
            pattern_type=config.KEYWORD_PATTERN_TYPE,
            min_pattern_support=config.MIN_KEYWORD_PATTERN_SUPPORT,
            visualize_intermediate_trees_flag=config.VISUALIZE_INTERMEDIATE_TREES_FLAG
        )
    _logger.debug("KeywordTree extraction took %.4f seconds" % (time.time() - tttt))
    del tttt
    _logger.info("#" * 28 + " CREATED A KEYWORDTREE " + "#" * 29 + "\n")
# Out:
# INFO:root:############################ CREATING A KEYWORDTREE ############################
# INFO:socialtree_functions:-------------------------- EXTRACTING THE TAG PROFILE --------------------------
# INFO:profile_functions:started replacing the lexiacally redundant tags
# INFO:profile_functions:--- started the story tag profile extraction ---
# INFO:profile_functions:initially there were 939 tags selected for story's profile keyword_profile
# INFO:common.pattern_functions:read the rules from 'patterns/story_patterns_independence_keyword_profile_rules.out' and produced a df of shape (2996, 11)
# INFO:common.pattern_functions:found 220 redundant sets of items with 100% conditional probability of co-occurrence on both directions,
# as a result, 426 items will be removed from the item profile and later will be added to their co-occurring items
# INFO:profile_functions:after the redundancy removal, 513 tags compose story's profile keyword_profile
# INFO:profile_functions:the cuttoff point should be ('election$', 0.0038868342718571458) based on max dist
# INFO:profile_functions:--- finished the story keyword_profile profile extraction in 0.624 seconds (6.0 seconds since start) ---
# INFO:profile_functions:--- finished the keyword_profile plot preparations in 1.084 seconds (7.1 seconds since start) ---
# INFO:socialtree_functions:-------------------------- EXTRACTED THE TAG PROFILE ---------------------------
# INFO:socialtree_functions:------------------------------ CREATING A TAG TREE -----------------------------
# INFO:common.pattern_functions:read the patterns from 'patterns/story_patterns_independence_keywords_list_frequent.out' and produced a df of shape (170, 5)
# INFO:common.pattern_functions:there are 170 patterns with support>=-2 mined from the retrieved documents
# INFO:socialtree_functions:--- mined frequent patterns in 0.049 seconds (7.1 seconds since start) ---
# INFO:socialtree_functions:--- starting the graph construction and the tree extraction ---
# DEBUG:common.pattern_functions:finished getting the document ids for patterns of length 2 in 0.01 sec
# DEBUG:common.pattern_functions:finished getting the document ids for patterns of length 3 in 0.01 sec
# DEBUG:common.pattern_functions:finished getting the document ids for patterns of length 4 in 0.01 sec
# INFO:common.graph_functions:there are 28 nodes with 91 edges + 1 isolates with support>=1
# INFO:socialtree_functions:--- constructed the graph in 0.013 seconds (7.5 seconds since start) ---
# INFO:socialtree_functions:--- set the node attributes in 0.084 seconds (7.6 seconds since start) ---
# <div id="a4e01a21-280f-43fa-a43d-978b90a64cca" style="height: 720.0px; width: 1320px;" class="plotly-graph-div"></div><script type="text/javascript">require(["plotly"], function(Plotly) { window.PLOTLYENV=window.PLOTLYENV || {};window.PLOTLYENV.BASE_URL="https://plot.ly";Plotly.newPlot("a4e01a21-280f-43fa-a43d-978b90a64cca", [{"hoverinfo": "none", "line": {"color": "#888", "width": 1.0606060606060606}, "mode": "lines", "x": [-0.09152352784340757, 0.14705421108110342, null], "y": [-0.35002086602004273, 0.04490472848886539, null], "type": "scatter", "uid": "3eb4806b-0c67-46fa-b737-12036ecd3634"}, {"hoverinfo": "none", "line": {"color": "#888", "width": 4.545454545454546}, "mode": "lines", "x": [-0.09152352784340757, -0.24051933637756442, null], "y": [-0.35002086602004273, -0.22338882666883764, null], "type": "scatter", "uid": "07825584-9f6c-40f0-bee6-dcf66f94fadf"}, {"hoverinfo": "none", "line": {"color": "#888", "width": 4.090909090909091}, "mode": "lines", "x": [-0.09152352784340757, -0.1622481396726605, null], "y": [-0.35002086602004273, -0.16723175487847028, null], "type": "scatter", "uid": "a997c4cc-606b-4299-8f9b-8d68192d1792"}, {"hoverinfo": "none", "line": {"color": "#888", "width": 1}, "mode": "lines", "x": [-0.09152352784340757, -0.17237429066056245, null], "y": [-0.35002086602004273, 0.18076692038713327, null], "type": "scatter", "uid": "c65618b9-87c9-4a6b-874a-b8a036a9a05e"}, {"hoverinfo": "none", "line": {"color": "#888", "width": 1}, "mode": "lines", "x": [-0.09152352784340757, -0.4118920866305225, null], "y": [-0.35002086602004273, -0.2956933261000558, null], "type": "scatter", "uid": "f4c163ba-8c08-419a-8604-4ad0482e9734"}, {"hoverinfo": "none", "line": {"color": "#888", "width": 1}, "mode": "lines", "x": [-0.09152352784340757, -0.1304347264349748, null], "y": [-0.35002086602004273, -0.562526128261443, null], "type": "scatter", "uid": "9c6857a6-dd6f-4cf3-92e5-1e5e6e9cbeb5"}, {"hoverinfo": "none", "line": {"color": "#888", "width": 1}, "mode": "lines", "x": [-0.09152352784340757, -0
# # extract a TFIDFTree

# %% [raw]
# if config.CREATE_TFIDFTREE_FLAG:
#     _logger.info(
#         "Please crawl the articles and extract the TFIDF vectors of documents. "
#         "We can't provide those due to copyright issues, but the code below should run fine!"
#     )
#     tttt = time.time()
#     keyword_score_dict, timing_marks, story_info, keyword_recall_div, keyword_profile_div, \
#     k_support_div, g_div_k, t_plain_div_k, t_days_div_k, t_tag_profile_div_k, t_basic_div_k, t_simple_div_k, t_div_k = \
#         visualize_trees_and_graphs(
#             story_id=story_id,
#             articles_df=summary_articles_df.copy(),
#             timing_marks=timing_marks,
#             story_info=story_info,
#             tag_profile_field_name=config.TFIDFTREE_TAG_PROFILE_FIELD,
#             tag_blacklist=config.KEYWORD_BLACKLIST,
#             redundancy_conf_thres=config.KEYWORD_REDUNDANCY_CONF_THRES,
#             lexical_redundancy_prefix=config.KEYWORD_LEXICAL_REDUNDANCY_PREFIX,
#             lexical_redundancy_suffix=config.KEYWORD_LEXICAL_REDUNDANCY_SUFFIX,
#             min_profile_size=config.MIN_KEYWORD_PROFILE_SIZE,
#             plot_stats_flag=config.PLOT_KEYWORD_PROFILE_STATS_FLAG,
#             tag_list_field_name=config.TFIDFTREE_TAG_LIST_FIELD,
#             tag_field_blacklist=config.KEYWORD_BLACKLIST,
#             visualize_tree_flag=config.CREATE_KEYWORDTREE_FLAG,
#             importance_weighting_mode=config.KEYWORD_IMPORTANCE_WEIGHTING_MODE,
#             story_distance_resolution=config.KEYWORD_SUBSTORY_DISTANCE_RESOLUTION,
#             pattern_type=config.KEYWORD_PATTERN_TYPE,
#             min_pattern_support=config.MIN_KEYWORD_PATTERN_SUPPORT,
#             visualize_intermediate_trees_flag=config.VISUALIZE_INTERMEDIATE_TREES_FLAG
#         )
#     _logger.debug("KeywordTree extraction took %.4f seconds" % (time.time() - tttt))
#     del tttt
#     _logger.info("#" * 28 + " CREATED A KEYWORDTREE " + "#" * 29 + "\n")

# %% [markdown]
# # extract a WordCloud

# %% [raw]
# if config.CREATE_WORDCLOUD_FLAG:
#     wordcloud_file_name = create_word_cloud(
#         summary_articles_df[config.WORDCLOUD_CONTENT_FIELD_NAME].tolist(),
#         name=config.WORDCLOUD_CONTENT_FIELD_NAME, story_id=story_id,
#         max_words=config.WORDCLOUD_MAX_WORDS, min_font_size=8, width=1600, height=600, return_file_name=True
#     )

# %% [markdown]
# # extract a KeyGraph

# %% [raw]
# if config.CREATE_KEYGRAPH_FLAG:
#     keygraph_div = make_keygraph(
#         summary_articles_df.copy(),
#         story_id,
#         timing_marks,
#         content_field_name=config.KEYGRAPH_CONTENT_FIELD_NAME,
#         plot_graph=True,
#         conffile_name=config.KEYGRAPH_CONFFILE_NAME
#     )

# %% [markdown]
# # extract a MetroMap

# %% [raw]
# if config.CREATE_METROMAP_FLAG:
#     metromap_div = make_metromap(
#         articles_df=summary_articles_df.copy(),
#         story_id=story_id,
#         content_field_name=config.METROMAP_CONTENT_FIELD_NAME
#     )
